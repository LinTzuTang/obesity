# %%
import sys
sys.path.append('/home/obesity')
from bmi.data_preprocessing import write_train_validation_snp_data, write_test_snp_data

# %%
# Male
ped_path = '/home/obesity/input_data/ped_0106/0107male_train_bin_clump_snp_qc_ped.ped'
test_ped_path = '/home/obesity/input_data/ped_0106/0107male_test_bin_clump_snp_qc_ped.ped'
output_root='/home/obesity/snp_data/snp_data_0106' 
write_train_validation_snp_data(ped_path, output_root, gender='Male')
write_test_snp_data(test_ped_path, output_root, gender='Male')

# %%
# Female
ped_path = '/home/obesity/input_data/ped_1112/1105female_train_qc_clump_ped.ped'
test_ped_path = '/home/obesity/input_data/ped_1112/1105female_test_ped.ped'
output_root='/home/obesity/snp_data/snp_data_1112' 
write_train_validation_snp_data(ped_path, output_root, gender='Female')
write_test_snp_data(test_ped_path, output_root, gender='Female')
# Out:
#                   id SNP_1 SNP_2 SNP_3 SNP_4 SNP_5 SNP_6 SNP_7 SNP_8 SNP_9  \
# 0     TV2A_20190102G    CC    CG    GA    CC    TC    GG    AG    CT    CC
# 1     TV2A_20190102H    CC    CG    AA    CC    TC    GG    GG    CT    CC
# 2     TV2A_20190112C    CC    CG    AA    CC    CC    GG    AG    TT    CC
# 3     TV2A_20190303G    CC    GG    AA    CC    CC    GG    AG    TT    CC
# 4     TV2A_20190304C    CC    GG    AA    CC    CC    GG    AG    TT    CC
# ...              ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2274  TV29_20183707E    CC    GG    GA    CC    CC    GG    GG    TT    CC
# 2275  TV29_20183810E    CC    GG    GA    CC    CC    GG    GG    TT    CC
# 2276  TV29_20183811C    CC    GG    GA    CC    CC    GG    GG    CT    CC
# 2277  TV29_20183905D    CC    CG    AA    CC    CC    GG    GG    CT    CC
# 2278  TV29_20183912B    CC    GG    AA    CC    CC    GG    AG    TT    CC
#
# ...

# %%
1
# Out:
# 1
